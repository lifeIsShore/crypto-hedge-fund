# %% [markdown]
# # 00 — Data Pipeline
# > Fetch and save all raw data. **Never modify files in `/data/raw/` after this step.**

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'utils'))
from data_loader import fetch_price_data, fetch_macro_data, fetch_fundamentals, get_data_summary

# ── Config ────────────────────────────────────────────────
START = "2014-01-01"
FORCE = False  # Set True to re-download everything

# ── Fetch price data ──────────────────────────────────────
prices = fetch_price_data(start=START, force_refresh=FORCE)
print(f"Loaded {len(prices)} tickers")

# ── Fetch macro data ──────────────────────────────────────
macro = fetch_macro_data(start=START, force_refresh=FORCE)
print(f"Macro shape: {macro.shape}")
macro.tail(3)
# Out:
# Loaded 10 tickers
# Macro shape: (4509, 8)
#             fed_funds  yield_10y  yield_2y    vix  cpi_yoy       dxy  \
# Date
# 2026-05-04       3.64       4.45      3.95  18.29  330.293  118.3926
# 2026-05-05       3.64       4.43      3.93  17.38  330.293  118.3926
# 2026-05-06       3.64       4.36      3.87  17.39  330.293  118.3926
#
#             yield_curve  vix_change_5d
# Date
# 2026-05-04         0.50      -0.027645
# 2026-05-05         0.50       0.029011
# 2026-05-06         0.49       0.023543

# %%
# ── Fetch fundamentals ───────────────────────────────────
fundamentals = fetch_fundamentals(force_refresh=FORCE)
print("Fundamentals loaded for:", list(fundamentals.keys()))

# ── Summary ───────────────────────────────────────────────
summary = get_data_summary()
display(summary)
# Out:
# Fundamentals loaded for: ['META', 'JPM', 'XOM', 'UNH', 'TSLA', 'MSFT', 'CAT', 'AMZN', 'GLD', 'BRK-B']
#   ticker                  sector  price_rows price_start   price_end  \
# 0   META  Communication Services        3105  2014-01-02  2026-05-07
# 1    JPM              Financials        3105  2014-01-02  2026-05-07
# 2    XOM                  Energy        3105  2014-01-02  2026-05-07
# 3    UNH              Healthcare        3105  2014-01-02  2026-05-07
# 4   TSLA  Consumer Discretionary        3105  2014-01-02  2026-05-07
# 5   MSFT              Technology        3105  2014-01-02  2026-05-07
# 6    CAT             Industrials        3105  2014-01-02  2026-05-07
# 7   AMZN  Consumer Discretionary        3105  2014-01-02  2026-05-07
# 8    GLD             Commodities        3105  2014-01-02  2026-05-07
# 9  BRK-B             Diversified        3105  2014-01-02  2026-05-07
#
#    has_fundamentals
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
